# %%
import numpy as np

arr1d=np.array([1 , 2, 3, 4, 5])

slice_arr1d=arr1d[1:4]

print("arr1d:",arr1d )

print("Sclicing arr1d from 1 to 3:",slice_arr1d)
# Out:
# arr1d: [1 2 3 4 5]
# Sclicing arr1d from 1 to 3: [2 3 4]
