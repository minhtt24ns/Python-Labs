# %%
import numpy as np

arr=np.array([1 , 2, 3, 4, 5])

print("arr:",arr)
print("Shape ofarr:",arr.shape)
print("Size ofarr:",arr.size)
print("Data type ofarr:",arr.dtype)
print("Number of dimensions ofarr:",arr.ndim)
# Out:
# arr: [1 2 3 4 5]
# Shape ofarr: (5,)
# Size ofarr: 5
# Data type ofarr: int64
# Number of dimensions ofarr: 1
