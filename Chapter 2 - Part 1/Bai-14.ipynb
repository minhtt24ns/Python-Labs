# %%
from math import *

a = int(input("Nhap so nguyen a: "))
b = int(input("Nhap so nguyen b: "))

print("Tong cua a va b = ", a+b)
print("Hieu cua a va b = ", a-b)
print("Tich cua a va b = ", a*b)
print("Thuong cua a va b = ", a/b)
print("Phan con lai khi a chia b = ", a%b)
print("Logarit cơ số 10 của a = ", log10(a))
print("a luy thua b = ", a**b)
# Out:
# Nhap so nguyen a:  20
# Nhap so nguyen b:  10
# Tong cua a va b =  30
# Hieu cua a va b =  10
# Tich cua a va b =  200
# Thuong cua a va b =  2.0
# Phan con lai khi a chia b =  0
# Logarit cơ số 10 của a =  1.3010299956639813
# a luy thua b =  10240000000000
