# %%
from math import *

vi = 0
a = 9.8
d = float(input("Nhập độ cao vật được thả (m): "))

vf = sqrt((vi**2)+2*a*d)

print("Tốc độ di chuyển của vật khi nó chạm đất: ", vf, "m/s")
# Out:
# Nhập độ cao vật được thả (m):  10
# Tốc độ di chuyển của vật khi nó chạm đất:  14.0 m/s
