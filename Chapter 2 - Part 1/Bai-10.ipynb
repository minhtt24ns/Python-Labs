# %%
chieu_dai = float(input("Nhập chiều dài của căn phòng (m): "))
chieu_rong = float(input("Nhập chiều rộng của căn phòng (m): "))

dien_tich = chieu_dai * chieu_rong

print("Diện tích của căn phòng là:", dien_tich, "m²")
# Out:
# Nhập chiều dài của căn phòng (m):  10
# Nhập chiều rộng của căn phòng (m):  20
# Diện tích của căn phòng là: 200.0 m²
