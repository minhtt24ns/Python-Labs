# %%
chieu_dai = float(input("Nhập chiều dài  (m): "))
chieu_rong = float(input("Nhập chiều rộng (m): "))

S1 = chieu_dai * chieu_rong
S2 = S1/43.56
print("Diện tích của căn phòng là:", S1, "m²", "hay", S2, " Mẫu Anh")
# Out:
# Nhập chiều dài  (m):  10
# Nhập chiều rộng (m):  20
# Diện tích của căn phòng là: 200.0 m² hay 4.591368227731864  Mẫu Anh
