# %%
from math import *

cost = float(input("Nhập chi phí bữa ăn: "))

tax = cost * 0.05
tip = cost * 0.18
total = cost + tax + tip

print("Chi phí bữa ăn: ",round(cost,3))
print("Thuế: ", round(tax,2))
print("Tiền boa: ",round(tip,2))
print("Tổng cộng: ",round(total,2))
# Out:
# Nhập chi phí bữa ăn:  50.25
# Chi phí bữa ăn:  50.25
# Thuế:  2.51
# Tiền boa:  9.04
# Tổng cộng:  61.81
