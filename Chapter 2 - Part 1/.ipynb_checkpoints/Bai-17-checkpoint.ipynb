# %%
from math import *

T = float(input("Nhập nhiệt độ (độ C) : "))
V = float(input("Nhập tốc độ gió (km/h) : " ))

WCI = 13.12 + 0.6215*T - 11.37*(V**0.16) + 0.3965*T*(V**0.16)

print("Chỉ số gió lạnh là : ", round(WCI))
# Out:
# Nhập nhiệt độ (độ C) :  25.67
# Nhập tốc độ gió (km/h) :  10.25
# Chỉ số gió lạnh là :  27
