# %%
import math

a = float(input("Nhap do dai canh TG deu: "))
S = (a**2)*((math.sqrt(3))/4)

print("Dien tich TG deu: ", S)
# Out:
# Nhap do dai canh TG deu:  3
# Dien tich TG deu:  3.8971143170299736
