# %%
def average(a,b,c):
    avg = (a+b+c)/3
    return avg

a = float(input("Nhập số nguyên thứ nhất: "))
b = float(input("Nhập số nguyên thứ hai: "))
c = float(input("Nhập số nguyên thứ ba: "))

kq = average(a,b,c)
print("Giá trị trung bình của chúng = " + str(kq))
# Out:
# Nhập số nguyên thứ nhất:  4
# Nhập số nguyên thứ hai:  5
# Nhập số nguyên thứ ba:  6
# Giá trị trung bình của chúng = 5.0
