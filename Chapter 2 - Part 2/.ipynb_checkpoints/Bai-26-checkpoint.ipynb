# %%
ch = input("Nhập 1 kí tự: ")

if ch=="a" or ch=="e" or ch=="i" or ch=="o" or ch=="u" :
    print("Chữ đã nhập là nguyên âm")
elif ch=="y" :
    print("Có thể là nguyên âm hoặc phụ âm")
else :
    print("Chữ đã nhập là phụ âm")
# Out:
# Nhập 1 kí tự:  e
# Chữ đã nhập là nguyên âm
