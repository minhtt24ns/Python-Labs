# %%
    n = int(input("Vui lòng nhập một số nguyên dương n: "))

    for i in range(1, n + 1):
        ket_qua[i] = i * i

    print(str(ket_qua))
# Out:
# Vui lòng nhập một số nguyên dương n:  5
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
